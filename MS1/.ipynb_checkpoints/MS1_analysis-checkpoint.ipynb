# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib as plb
import seaborn as sns
from scipy import stats
import statistics
import dabest
from skimage.io import imread
from pandas.api.types import CategoricalDtype
from scipy.ndimage import rotate

# %%
analysis_data = pd.DataFrame()
analysis_path = plb.Path('D:/_2021_08_screen/practice_run/auto_results/')

# %%
analysis_data = pd.read_csv('D:/_2021_08_screen/practice_run/ia_927/MS1.csv', index_col=0)
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis  Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       NaN     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       NaN     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       NaN     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       NaN     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       NaN     NaN   MS1_006      3049.0
#
#    Plate ID  Large Object
# 0       NaN         False
# 1       NaN          True
# 2       NaN          True
# 3       NaN         False
# 4       NaN          True

# %%
for dat in analysis_path.glob('MS1*.csv'):
    hold = pd.read_csv(dat, index_col=0)
    analysis_data = pd.concat([analysis_data, hold], axis=0)
    
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis  Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       NaN     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       NaN     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       NaN     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       NaN     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       NaN     NaN   MS1_006      3049.0
#
#    Plate ID  Large Object
# 0       NaN         False
# 1       NaN          True
# 2       NaN          True
# 3       NaN         False
# 4       NaN          True

# %%
metadata = pd.read_csv('D:/_2021_08_screen/practice_run/data/20210812_metadata.csv', index_col=0)
metadata.head()
# Out:
#          Recorder    Plate ID  \
# Date:
# 08/12/21   Emily   MS1_R1_001
# 08/12/21    Hodan  MS1_R1_008
# 08/12/21    Emily  MS1_R1_002
# 08/12/21    Emily  MS1_R1_003
# 08/12/21    EMILY  MS1_R1_004
#
#          Different strains in each well of a single assay plate? (Y/N)  \
# Date:
# 08/12/21                                                  N
# 08/12/21                                                  N
# 08/12/21                                                  N
# 08/12/21                                                  N
# 08/12/21                                                  N
#
#          Different compounds in each well of a single assay plate? (Y/N)  \
# Date:
# 08/12/21                                                  Y
# 08/12/21                                                  Y
# 08/12/21                                                  Y
# 08/12/21                                                  Y
# 08/12/21                                                  Y
#
#          Compound library ID Compound Well A Compound Well B Compound Well C  \
# Date:
# 08/12/21                 1-1              B2              B3              B4
# 08/12/21                 1-2              B2              B3              B4
# 08/12/21                 1-1              C2              C3              C4
# 08/12/21                 1-1              D2              D3              D4
# 08/12/21                 1-1              E2              E3              E4
#
#          Compound Well D  Temp (C)  Humidity  \
# Date:
# 08/12/21              B5       NaN       NaN
# 08/12/21              B5       NaN       NaN
# 08/12/21              C5       NaN       NaN
# 08/12/21              D5       NaN       NaN
# 08/12/21              E5       NaN       NaN
#
#           Chemotaxis Start (24 hrs format)  Chemotaxis End (24 hrs format)  \
# Date:
# 08/12/21                               NaN                             NaN
# 08/12/21                               NaN                             NaN
# 08/12/21                               NaN                             NaN
# 08/12/21                               NaN                             NaN
# 08/12/21                               NaN                             NaN
#
#          Image ID  Scanner Slot:  Scanner #  Strain Well A   Strain Well B  \
# Date:
# 08/12/21  MS1_001              1        NaN             NaN            NaN
# 08/12/21  MS1_002              4        NaN             NaN            NaN
# 08/12/21  MS1_001              2        NaN             NaN            NaN
# 08/12/21  MS1_001              3        NaN             NaN            NaN
# 08/12/21  MS1_001              4        NaN             NaN            NaN
#
#           Strain Well C  Strain Well D
# Date:
# 08/12/21            NaN            NaN
# 08/12/21            NaN            NaN
# 08/12/21            NaN            NaN
# 08/12/21            NaN            NaN
# 08/12/21            NaN            NaN

# %%
# Breaking up the slot and well info to use for unblinding the compound data
for index, row in analysis_data.iterrows():
    analysis_data['Slot']= analysis_data['WellNo'].astype(str).str[0]
    analysis_data['Well']= analysis_data['WellNo'].astype(str).str[1]

# Adding the plate ID to the image analysis results
def add_pid(row, image_metdat):
    pid = image_metdat.loc[(image_metdat['Image ID']==row['File Name']) 
                           & (image_metdat['Scanner Slot:'].astype(str)==row['Slot'])]['Plate ID']
    return pid

# %%
analysis_data['Plate ID']=analysis_data.apply(
    lambda row: add_pid(row, metadata), axis=1)
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis  Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       NaN     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       NaN     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       NaN     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       NaN     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       NaN     NaN   MS1_006      3049.0
#
#      Plate ID  Large Object Slot Well
# 0  MS1_R1_013         False    1    A
# 1  MS1_R1_013          True    1    B
# 2  MS1_R1_013          True    1    C
# 3  MS1_R1_013         False    1    D
# 4  MS1_R1_014          True    2    A

# %%
# Creating a function to map the compound key to the automated image analysis
# results
def f(x):
    return {
        'A': 'Compound Well A',
        'B': 'Compound Well B',
        'C': 'Compound Well C',
        'D': 'Compound Well D',
    }[x]

def add_compound(row, image_metdat):
    well=row['Well']
    dat = image_metdat.loc[image_metdat['Plate ID']==row['Plate ID']][f(well)]
    return dat.values[0]

analysis_data['Compound']=analysis_data.apply(
    lambda row: add_compound(row, metadata), axis=1)

analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       B2     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       B3     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       B4     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       B5     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       C2     NaN   MS1_006      3049.0
#
#      Plate ID  Large Object Slot Well
# 0  MS1_R1_013         False    1    A
# 1  MS1_R1_013          True    1    B
# 2  MS1_R1_013          True    1    C
# 3  MS1_R1_013         False    1    D
# 4  MS1_R1_014          True    2    A

# %%
def add_compound_plate(row, image_metdat):
    comp_plate = image_metdat.loc[image_metdat['Plate ID'] == row['Plate ID']]['Compound library ID']
    return comp_plate

analysis_data['Compound Library ID']=analysis_data.apply(
    lambda row: add_compound_plate(row, metadata), axis=1)
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       B2     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       B3     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       B4     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       B5     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       C2     NaN   MS1_006      3049.0
#
#      Plate ID  Large Object Slot Well Compound Library ID
# 0  MS1_R1_013         False    1    A                 1-4
# 1  MS1_R1_013          True    1    B                 1-4
# 2  MS1_R1_013          True    1    C                 1-4
# 3  MS1_R1_013         False    1    D                 1-4
# 4  MS1_R1_014          True    2    A                 1-4

# %%
def flip(row):
    id = row['Compound']
    flipped = id[::-1]
    #print(flipped)
    return(flipped)

analysis_data['Compound']=analysis_data.apply(
    lambda row: flip(row), axis=1)

# %%
compound_data = pd.read_csv('D:/_2021_08_screen/practice_run/compounds/comp_plate_map.csv', index_col=0)
compound_data.head()
# Out:
#    Num Let Compounds Compound Well Plate Number
# 0    2   B        IA            2B          1-1
# 1    3   B        DI            3B          1-1
# 2    4   B        DI            4B          1-1
# 3    5   B       EMT            5B          1-1
# 4    2   C        DI            2C          1-1

# %%
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       2B     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       3B     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       4B     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       5B     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       2C     NaN   MS1_006      3049.0
#
#      Plate ID  Large Object Slot Well Compound Library ID
# 0  MS1_R1_013         False    1    A                 1-4
# 1  MS1_R1_013          True    1    B                 1-4
# 2  MS1_R1_013          True    1    C                 1-4
# 3  MS1_R1_013         False    1    D                 1-4
# 4  MS1_R1_014          True    2    A                 1-4

# %%
def unblind(row, comp_dat):
    comp_name = comp_dat.loc[(comp_dat['Compound Well'] == row['Compound']) & 
                             (comp_dat['Plate Number'] == row['Compound Library ID'])]['Compounds']
    return comp_name.values[0]
    

analysis_data['Compound Name']=analysis_data.apply(
    lambda row: unblind(row, compound_data), axis=1)

analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       2B     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       3B     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       4B     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       5B     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       2C     NaN   MS1_006      3049.0
#
#      Plate ID  Large Object Slot Well Compound Library ID Compound Name
# 0  MS1_R1_013         False    1    A                 1-4           EMT
# 1  MS1_R1_013          True    1    B                 1-4          Benz
# 2  MS1_R1_013          True    1    C                 1-4           EMT
# 3  MS1_R1_013         False    1    D                 1-4            DI
# 4  MS1_R1_014          True    2    A                 1-4            DI

# %%
analysis_data=analysis_data.replace('Benz', '1-Oct')

# %%
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis Compound  Strain File Name  Well width  \
# 0     1A        324.0    0.132867       2B     NaN   MS1_006      3028.0
# 1     1B        266.0    0.044643       3B     NaN   MS1_006      3019.0
# 2     1C        209.0    0.067416       4B     NaN   MS1_006      3009.0
# 3     1D        343.0   -0.082508       5B     NaN   MS1_006      3013.0
# 4     2A        194.0    0.793103       2C     NaN   MS1_006      3049.0
#
#      Plate ID  Large Object Slot Well Compound Library ID Compound Name
# 0  MS1_R1_013         False    1    A                 1-4           EMT
# 1  MS1_R1_013          True    1    B                 1-4         1-Oct
# 2  MS1_R1_013          True    1    C                 1-4           EMT
# 3  MS1_R1_013         False    1    D                 1-4            DI
# 4  MS1_R1_014          True    2    A                 1-4            DI

# %%
#analysis_data.to_csv('/Volumes/LaCie/_2021_08_screen/practice_run/MS1_analysis.csv')

# %%
summary_data = analysis_data.groupby(['Compound Name']).mean()

# %%
#summary_data = summary_data.drop(['Large Object'], axis=1)

#summary_data.to_csv('D:/_2021_08_screen/practice_run/data/RefComps_sumstats.csv')

# %%
#summary_data = pd.read_csv('D:/_2021_08_screen/practice_run/data/RefComps_sumstats.csv')

# %%
ref_list = ['DMSO', 'Empty', 'DI', 'IA', '2-no', '1-oct']

# %%
impath = 'D:/_2021_08_screen/practice_run/representatives/'
image_folder = plb.Path(impath)
fig, axes = plt.subplots(nrows=1, ncols=6, sharey=True, sharex=True)


col = 0
row = 1
for i in ref_list:
#im in image_folder.glob('[!._]*.tif*'):
    
    im = image_folder.joinpath(i + '.tiff')
    img = imread(im)
    center = (img.shape[0])/2
    fname = im.stem
    axes[col].imshow(img/255, cmap='gray')
    axes[col].set_title(fname)
    #axes[col].axis('off')
    axes[col].xaxis.set_visible(False)
    axes[col].axhline(y=center, color='r', linestyle='--')
    col += 1

fig.savefig('D:/_2021_08_screen/practice_run/figs/plot.tiff', dpi=1200)

# %%
wrm_locs_fldr = plb.Path('D:/_2021_08_screen/practice_run/ia_927/')

# %%
def get_worm_locs(row, wrms, result_dict): 

    fname = row['File Name']
    wellnum = row['WellNo']
    loc_fname =  wrms.joinpath('loc_' + fname + '_' + wellnum + '.csv')
    temp = pd.read_csv(loc_fname)
    compound = row['Compound Name']
    xs = temp['X']
    #xs = list(temp['centroid-1'])
    if compound in result_dict:
        result_dict[compound] = result_dict[compound].append(xs)
        result_dict[compound].reset_index(inplace=True, drop=True)
        #result_dict[compound] = result_dict[compound]+xs
    else:
        result_dict[compound]=xs
    
    return result_dict

ref_dict = {}
for index, row in analysis_data.iterrows():
    ref_locs = get_worm_locs(row, wrm_locs_fldr, ref_dict)
ref_df = pd.DataFrame.from_dict(ref_dict)
ref_df.head()
# Out:
#     EMT   1-Oct      DI    DMSO      IA     2no
# 0  2078  2681.0  2329.0  1201.0   405.0  2061.0
# 1  1803  2309.0  1952.0  1406.0   482.0  1448.0
# 2  1740  1884.0  2377.0  2240.0  1320.0  1354.0
# 3  2023  1348.0  1891.0   808.0   886.0   687.0
# 4   368  1329.0  2137.0  2674.0  1356.0  1078.0

# %%
#ref_df.to_csv('D:/_2021_08_screen/practice_run/wormX_ref_comps.csv')

# %%
# 1 inch = 25.4mm
mm = 25.4
# 1200 pixels per 25.4mm
px_mm = 1200/mm
#pixels per milimeter
px_mm

mm_df = ref_df.apply(lambda x: -(x/px_mm)+32.5)

# %%
mm_df.head()
# Out:
#          EMT      1-Oct         DI       DMSO         IA        2no
# 0 -11.484333 -24.247833 -16.797167   7.078833  23.927500 -11.124500
# 1  -5.663500 -16.373833  -8.817333   2.739667  22.297667   1.850667
# 2  -4.330000  -7.378000 -17.813167 -14.913333   4.560000   3.840333
# 3 -10.320167   3.967333  -7.526167  15.397333  13.746333  17.958500
# 4  24.710667   4.369500 -12.733167 -24.099667   3.798000   9.682333

# %%
ref_comps=['DMSO', 'EMT', 'DI', 'IA', '1-Oct', '2no']
color_dict={'DMSO':'#5e4fa2', 'EMT':'#5e4fa2', 'DI':'#66c2a5', 'IA':'#66c2a5', '1-Oct':'#fdae61', '2no':'#fdae61'}

# %%
mm_refs_obj = dabest.load(mm_df, idx=(ref_comps))

# %%
mm_refs_plot = mm_refs_obj.mean_diff.plot(raw_marker_size=1, swarm_label = 'Worm Locations \nwithin the arena (mm)', 
                                        contrast_label="Mean differene (mm)", contrast_ylim = (-20,20), swarm_ylim=(-35,35), custom_palette=color_dict)
rawswarm_axes = mm_refs_plot.axes[0]
contrast_axes = mm_refs_plot.axes[1]

rawswarm_axes.yaxis.set_tick_params(tickdir='in')
rawswarm_axes.xaxis.set_tick_params(tickdir='in')

contrast_axes.remove()
#contrast_axes.yaxis.set_tick_params(tickdir='in')
#contrast_axes.xaxis.set_tick_params(tickdir='in')
# Out:
# C:\ProgramData\Anaconda3\envs\neuroplant\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mm_refs_plot.savefig('D:/_2021_08_screen/practice_run/20210812_conf_int.png')
# Out:
# C:\ProgramData\Anaconda3\envs\neuroplant\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   """Entry point for launching an IPython kernel.

# %%
analysis_data.head()
# Out:
#   WellNo  Total Worms  Chemotaxis Compound  Strain File Name    Plate ID Slot  \
# 0     1A        202.0    0.469136       2B     NaN   MS1_001  MS1_R1_001    1
# 1     1B        180.0    0.371795       3B     NaN   MS1_001  MS1_R1_001    1
# 2     1C        152.0    0.572519       4B     NaN   MS1_001  MS1_R1_001    1
# 3     1D        344.0   -0.065359       5B     NaN   MS1_001  MS1_R1_001    1
# 4     2A        265.0    0.399103       2C     NaN   MS1_001  MS1_R1_002    2
#
#   Well Compound Library ID Compound Name
# 0    A                 1-1            IA
# 1    B                 1-1            DI
# 2    C                 1-1            DI
# 3    D                 1-1           EMT
# 4    A                 1-1            DI

# %%
cat_size_order = CategoricalDtype(
    ['DMSO', 'EMT', '2no', '1-Oct', 'DI', 'IA'], 
    ordered=True)
analysis_data.sort_values('Compound Name')

analysis_data['Compound Name'] = analysis_data['Compound Name'].astype(cat_size_order)

ax = sns.boxplot(x="Compound Name", y="Chemotaxis", data=analysis_data, palette=agg_color_dict)
plt.savefig('/Volumes/LaCie/_2021_08_screen/practice_run/MS1_box.png')

# %%
ax = sns.boxplot(x="Compound Name", y="Total Worms", data=analysis_data, palette=agg_color_dict)
plt.savefig('/Volumes/LaCie/_2021_08_screen/practice_run/MS1_tw.png')
