# %% [markdown]
# # Many of the
#
# ### It does not include a __main__() and should be run as a notebook from the top down.
# <p> It is also intended as a place for testing

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import time
import skimage
from skimage import io
from skimage import feature
from skimage import morphology
from skimage import measure
from skimage import exposure
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy import ndimage as ndi
import numpy as np
import pathlib
import csv

# %% [markdown]
# ## Set File paths

# %%
base_folder = pathlib.Path('/Users/emilyfryer/Desktop/Neuroplant/')
image_location = base_folder.joinpath('Images')
results_location = base_folder.joinpath('automated_results')
metadata_location = base_folder.joinpath('metadata')

# %% [markdown]
# ## Load the Image and Batch Metadata
#
# * There are 2 forms used to collect the metadata for the Neuroplant screens.
#      1. Image metadata contains: Name of imager, date, image filename (unique identifier), plate IDs, location on the 4-plate template, compound.
#      2. Batch metadata contains: Recorder's name, date, temperature, humidity, plate pour date, well and worm strain

# %%
image_metadata = pd.read_csv(metadata_location.joinpath('image_data.csv'))
batch_metadata = pd.read_csv(metadata_location.joinpath('feb_batch_data_mod.csv'))

image_metadata.rename(columns={'Name of individual capturing image:': 'imager',
                     'Date:': 'date',
                     "Image file name:": 'filename',
                     'Is this the pre or post assay image?': 'pre_fin',
                    'Plate number in slot 1:': 'slot1_plate',
                     'Plate number in slot 2:': 'slot2_plate',
                     'Plate number in slot 3:': 'slot3_plate',
                     'Plate number in slot 4:': 'slot4_plate', 
                               'Compound in slot 1:': 'slot1_compound', 
                               'Compound in slot 2:': 'slot2_compound', 
                               'Compound in slot 3:': 'slot3_compound', 
                               'Compound in slot 4:': 'slot4_compound',}, inplace=True)

batch_metadata.rename(columns={'Recorder\'s Name:': 'recorder',
                              'Date:': 'date',
                               'Temperature:': 'temp',
                              'Humidity:': 'humidity',
                              'Date chemotaxis plates were poured:': 'plates_poured',
                              'Worm Strain in Well P:': 'strain_wellP',
                              'Worm Strain in Well Q:.1': 'strain_wellQ',
                              'Worm Strain in Well R:.1': 'strain_wellR',
                              'Worm Strain in Well S:.1': 'strain_wellS',
                              'dates' : 'dates_modified',}, inplace = True )

batch_metadata['dates_modified'] = batch_metadata['dates_modified'].astype(str)

# %%
def get_plate_id(slot, image_pointer):
    file_name = image_pointer.resolve().stem[:] + '.tif'
    print(file_name)
    if slot == 1:
        data_list = image_metadata.loc[image_metadata['filename'] == file_name, ['slot1_plate', 'slot1_compound' ]].values.flatten().tolist()
        plate = data_list[0]
        compound = data_list[1]
    elif slot == 2:
        data_list = image_metadata.loc[image_metadata['filename'] == file_name, ['slot2_plate', 'slot2_compound' ]].values.flatten().tolist()
        plate = data_list[0]
        compound = data_list[1]
    elif slot == 3:
        data_list = image_metadata.loc[image_metadata['filename'] == file_name, ['slot3_plate', 'slot3_compound' ]].values.flatten().tolist()
        plate = data_list[0]
        compound = data_list[1]
    elif slot == 4:
        data_list = image_metadata.loc[image_metadata['filename'] == file_name, ['slot4_plate', 'slot4_compound' ]].values.flatten().tolist()
        plate = data_list[0]
        compound = data_list[1]
        
    return plate, compound

# %%
def get_strain(prefix, well_id):
    if well_id == 'P':
        strain_l = batch_metadata.loc[batch_metadata['dates_modified'] == prefix, ['strain_wellP']].values.flatten().tolist()
        strain = strain_l[0]
    elif well_id == 'Q':
        strain_l = batch_metadata.loc[batch_metadata['dates_modified'] == prefix, ['strain_wellQ']].values.flatten().tolist()
        strain = strain_l[0]
    elif well_id == 'R':
        strain_l = batch_metadata.loc[batch_metadata['dates_modified'] == prefix, ['strain_wellR']].values.flatten().tolist()
        strain = strain_l[0]
    elif well_id == 'S':
        strain_l = batch_metadata.loc[batch_metadata['dates_modified'] == prefix, ['strain_wellS']].values.flatten().tolist()
        strain = strain_l[0]
        
    return strain

# %% [markdown]
# ## Load raw images

# %%
def load_image_data(data_location, prefix, plate_id):
    
    fin_file = data_location.joinpath(prefix + '_fin' + suffix + '.tif' )
    fin_image = skimage.io.imread(fin_file)

    return fin_image

# %% [markdown]
# ## Crop images
#
# <p>Each image can contain up to 4 different plates. To count the worms in individual wells we need to:
#     1. Crop to individual plates
#     2. Crop to individual wells

# %%
def crop_to_one_plate(fin_image, slot_id):
    # select bounds of the slot we're working on now
    if slot_id == 1:
        upper_boundary = 220
        lower_boundary = 6246
        left_boundary = 6140
        right_boundary = 10144
    elif slot_id == 2:
        upper_boundary = 220
        lower_boundary = 6246
        left_boundary = 1484 
        right_boundary = 5488
    elif slot_id == 3:
        upper_boundary = 6940
        lower_boundary = 12966
        left_boundary = 1484
        right_boundary = 5488
    elif slot_id == 4:
        upper_boundary = 6940
        lower_boundary = 12966
        left_boundary = 6140
        right_boundary = 10144
    else:
        raise ValueError('Lane label not recognized.')

    fin_image = fin_image[upper_boundary:lower_boundary, left_boundary:right_boundary]
    
    return fin_image

# %%
def left_crop_to_one_well(fin_image, well_id):
    # select bounds of the lane we're working on now
    Left_boundary = 300
    Right_boundary = 3724
    if well_id == 'P':
        Upper_boundary = 265
        Lower_boundary = 1415
    elif well_id == 'Q':
        Upper_boundary = 1725
        Lower_boundary = 2875
    elif well_id == 'R':
        Upper_boundary = 3165
        Lower_boundary = 4315
    elif well_id == 'S':
        Upper_boundary = 4615
        Lower_boundary = 5765
    fin_image = fin_image[ Upper_boundary:Lower_boundary ,Left_boundary:Right_boundary ]
    
    return fin_image

def right_crop_to_one_well(fin_image, well_id):
    # select bounds of the lane we're working on now
    Left_boundary = 190
    Right_boundary = 3614
    if well_id == 'P':
        Upper_boundary = 265
        Lower_boundary = 1415
    elif well_id == 'Q':
        Upper_boundary = 1725
        Lower_boundary = 2875
    elif well_id == 'R':
        Upper_boundary = 3165
        Lower_boundary = 4315
    elif well_id == 'S':
        Upper_boundary = 4615
        Lower_boundary = 5765
    fin_image = fin_image[ Upper_boundary:Lower_boundary , Left_boundary:Right_boundary ]

    return fin_image

# %% [markdown]
# ### Identify worms in the images.
#
# # Get Median pixel intensity!
#
# <p> This method uses the median pixel intensity to binarize the image. <p>

# %%
def find_worms(fin_image):
    feature_find_start = time.time()
    
    mask = fin_image > 55
    masked_image = fin_image  * mask
    
    ## Subtract background
    #bkg_subtract = np.subtract(pre_image.astype('int16'),
    #                           fin_image.astype('int16'))
    
    #bkg_subtract = masked_image - fin_image
    #bkg_subtract[bkg_subtract < 0] = 0
    #bkg_subtract = bkg_subtract.astype('uint8')
 
    
    ## Threshold to get binary image
    #thresh = skimage.filters.threshold_otsu(fin_image)
    #binarized = bkg_subtract < thresh
    #print('Binarization threshold is', str(thresh))

    ## Find features in binary image
    labeled_array, num_features = ndi.label(masked_image)
    all_regions = measure.regionprops(label_image=labeled_array, intensity_image=fin_image,
                                      coordinates='rc')

    filtered_regions = []
    for region in all_regions:
        area = region.area

        if area >= 100 and area <=1000 and region.major_axis_length < 120:
            filtered_regions.append(region)
            #print(area)
            
#     print('Worm finding and filtering took', str(int(time.time() - feature_find_start)), 'seconds.')
    return filtered_regions

# %% [markdown]
# ### Save worm locations

# %%
def save_worm_locations(filename, worms):
    with open(filename, 'w', newline='') as csvfile:
        worm_writer = csv.writer(csvfile, delimiter=',')
        worm_writer.writerow([' ','X','Y']) # header row

        worm_num = 1
        for worm in worms:
            worm_writer.writerow([worm_num, worm.centroid[1], worm.centroid[0]])
            worm_num += 1

# %% [markdown]
# ### Calculate Chemotaxis Index

# %%
def calc_chemotaxis_index(worm_regions):
    ## Assign features to zones of the plate
#     left_area_boundary = 8700 #int(fin_image.shape[1]/3)
#     right_area_boundary = 12000 #int(2 * (fin_image.shape[1] / 3))
    
    
    left_area_boundary = int(3424*4/9) # These values can be adjusted to alter the # of bins
    right_area_boundary = int(3424*5/9)# for each analysis

    left_side_worms = [worm for worm in worm_regions if worm.centroid[1] <= left_area_boundary]
    middle_worms = [worm for worm in worm_regions 
                    if worm.centroid[1] > left_area_boundary and worm.centroid[1] < right_area_boundary]
    right_side_worms = [worm for worm in worm_regions if worm.centroid[1] >= right_area_boundary]


    ## Calculate chemotaxis index
    worms_in_left_region = len(left_side_worms)
    worms_in_middle_region = len(middle_worms)
    worms_in_right_region = len(right_side_worms)
    total_worms_found = len(worm_regions)

    
    chemotaxis_index = ((worms_in_left_region - worms_in_right_region) 
                        / (worms_in_left_region + worms_in_right_region))

  
    x_coords = []
    y_coords = []
    for worm in worm_regions:
#         x_sum += worm.centroid[0]
#         y_sum += worm.centroid[1]
        x_coords.append(worm.centroid[0])
        y_coords.append(worm.centroid[1])

    centroid = (sum(x_coords)/len(x_coords), sum(y_coords)/len(y_coords))

    return chemotaxis_index, centroid

# %% [markdown]
# ## Loop through all of the plates and wells

# %%
loop_start = time.time()
results = []
for image in image_location.glob('*fin*.tif'): #image_location.glob('scan*Fin.tif'): #
    plate_start = time.time()
    path = image.resolve()
    image_id = image.stem
    print(image_id)
    prefix = image.stem[0:8]
    suffix = image.stem[12:]
    bins = 15
    print(path)
    
    # Load the entire image
    fin_image = load_image_data(image_location, prefix, suffix)
    print('Image load took', str(int(time.time()-plate_start)), 'seconds.')
    
    
    for i in range(1,5):
        slot_id = i
        fin_cropped_2plate = crop_to_one_plate(fin_image, slot_id) 
        plate_id, compound = get_plate_id(slot_id, path)
        if plate_id == '0':
            break
        else:
            results_list = []
            for well_id in ['P', 'Q', 'R', 'S']:
                # Process one well at a time
                if slot_id == 1 or slot_id == 4:
                    cropped_fin_image = right_crop_to_one_well(fin_cropped_2plate, well_id)
                elif slot_id == 2 or slot_id == 3:
                    cropped_fin_image = left_crop_to_one_well(fin_cropped_2plate, well_id)
                
                # Identifying and counting worms
                worms = find_worms(cropped_fin_image)
                total_worms = len(worms)
                strain = get_strain(prefix, well_id)
                
                # Save the results
                filename = results_location.joinpath(prefix + '_' + plate_id + '_' + well_id + '_automatedCounts' + '.csv')
                save_worm_locations(filename, worms)

                # Calculate chemotaxis index and gather into a dataframe
                # Check total number of worms counted to avoid 'division by zero' errors 
                if total_worms == 0:
                    chemotaxis_index = 'NA'
                    results_dict = {'Date' : prefix,
                                'Filename': image_id,
                                'Well_id': well_id,
                                'Plate_id': plate_id,
                                'Strain_id' : strain,
                                'Compound_id' : compound,
                                'Total_Worms' : total_worms,
                                'Bin#' : bins,
                                'chemotaxis_index': chemotaxis_index,
                                'centroid_x': centroid[1],
                                'centroid_y': centroid[0]}
                    results_list.append(results_dict)
                    results.append(results_dict)

                    props = ['area', 'convex_area', 'bbox', 'centroid']
                    worm_df = pd.DataFrame([{prop: getattr(reg, prop) for prop in props} for reg in worms])
                
                else:

                    chemotaxis_index, centroid = calc_chemotaxis_index(worms)
                    results_dict = {'Date' : prefix,
                                    'Filename': image_id,
                                    'Well_id': well_id,
                                    'Plate_id': plate_id,
                                    'Strain_id' : strain,
                                    'Compound_id' : compound,
                                    'Total_Worms' : total_worms,
                                    'Bin#' : bins,
                                    'chemotaxis_index': chemotaxis_index,
                                    'centroid_x': centroid[1],
                                    'centroid_y': centroid[0]}
                    results_list.append(results_dict)
                    results.append(results_dict)

                    props = ['area', 'convex_area', 'bbox', 'centroid']
                    worm_df = pd.DataFrame([{prop: getattr(reg, prop) for prop in props} for reg in worms])

            #results_df = pd.DataFrame(results_list)
            #results_df.to_csv(path_or_buf=results_location.joinpath(prefix + '_' + plate_id + '_chemotaxis_summary.csv'))


            print('Finished', plate_id,'in', str(int(time.time()-plate_start)), 'seconds.')
    all_results_df = pd.DataFrame(results)
    all_results_df.to_csv(path_or_buf=base_folder.joinpath('to_compare.csv'))
        # results_df = pd.DataFrame(results_list)
        # results_df.to_csv(path_or_buf=base_folder.joinpath('chemotaxis_summary.csv'))
    print('Finished everything in', str(int(time.time()-loop_start)), 'seconds.')
# Out:
# 20200210_fin001
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200210_fin001.tif
# Image load took 0 seconds.
# 20200210_fin001.tif
# Finished NPS01_001 in 1 seconds.
# 20200210_fin001.tif
# Finished NPS01_002 in 3 seconds.
# 20200210_fin001.tif
# Finished NPS01_003 in 4 seconds.
# 20200210_fin001.tif
# Finished NPS01_004 in 6 seconds.
# Finished everything in 6 seconds.
# 20200210_fin002
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200210_fin002.tif
# Image load took 0 seconds.
# 20200210_fin002.tif
# Finished NPS01_005 in 2 seconds.
# 20200210_fin002.tif
# Finished NPS01_006 in 3 seconds.
# 20200210_fin002.tif
# Finished NPS01_007 in 5 seconds.
# 20200210_fin002.tif
# Finished NPS01_008 in 7 seconds.
# Finished everything in 13 seconds.
# 20200210_fin003
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200210_fin003.tif
# Image load took 0 seconds.
# 20200210_fin003.tif
# Finished NPS01_009 in 3 seconds.
# 20200210_fin003.tif
# Finished NPS01_010 in 5 seconds.
# 20200210_fin003.tif
# Finished NPS01_011 in 6 seconds.
# 20200210_fin003.tif
# Finished NPS01_012 in 7 seconds.
# Finished everything in 21 seconds.
# 20200228_fin017
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200228_fin017.tif
# Image load took 0 seconds.
# 20200228_fin017.tif
# Finished NPS01_065 in 1 seconds.
# 20200228_fin017.tif
# Finished NPS01_066 in 2 seconds.
# 20200228_fin017.tif
# Finished NPS01_067 in 4 seconds.
# 20200228_fin017.tif
# Finished NPS01_068 in 7 seconds.
# Finished everything in 28 seconds.
# 20200228_fin016
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200228_fin016.tif
# Image load took 0 seconds.
# 20200228_fin016.tif
# Finished NPS01_061 in 3 seconds.
# 20200228_fin016.tif
# Finished NPS01_062 in 7 seconds.
# 20200228_fin016.tif
# Finished NPS01_063 in 10 seconds.
# 20200228_fin016.tif
# Finished NPS01_064 in 12 seconds.
# Finished everything in 41 seconds.
# 20200217_fin007
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200217_fin007.tif
# Image load took 0 seconds.
# 20200217_fin007.tif
# Finished NPS01_025 in 3 seconds.
# 20200217_fin007.tif
# Finished NPS01_026 in 4 seconds.
# 20200217_fin007.tif
# Finished NPS01_027 in 7 seconds.
# 20200217_fin007.tif
# Finished NPS01_028 in 8 seconds.
# Finished everything in 50 seconds.
# 20200228_fin018
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200228_fin018.tif
# Image load took 0 seconds.
# 20200228_fin018.tif
# Finished NPS01_069 in 1 seconds.
# 20200228_fin018.tif
# Finished NPS01_070 in 2 seconds.
# 20200228_fin018.tif
# Finished NPS01_071 in 3 seconds.
# 20200228_fin018.tif
# Finished NPS01_072 in 4 seconds.
# Finished everything in 55 seconds.
# 20200214_fin004
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200214_fin004.tif
# Image load took 0 seconds.
# 20200214_fin004.tif
# Finished NPS01_013 in 3 seconds.
# 20200214_fin004.tif
# Finished NPS01_014 in 6 seconds.
# 20200214_fin004.tif
# Finished NPS01_015 in 7 seconds.
# 20200214_fin004.tif
# Finished NPS01_016 in 9 seconds.
# Finished everything in 64 seconds.
# 20200214_fin005
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200214_fin005.tif
# Image load took 0 seconds.
# 20200214_fin005.tif
# Finished NPS01_017 in 3 seconds.
# 20200214_fin005.tif
# Finished NPS01_018 in 4 seconds.
# 20200214_fin005.tif
# Finished NPS01_019 in 6 seconds.
# 20200214_fin005.tif
# Finished NPS01_020 in 7 seconds.
# Finished everything in 72 seconds.
# 20200217_fin009
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200217_fin009.tif
# Image load took 0 seconds.
# 20200217_fin009.tif
# Finished NPS01_033 in 1 seconds.
# 20200217_fin009.tif
# Finished NPS01_034 in 3 seconds.
# 20200217_fin009.tif
# Finished NPS01_035 in 5 seconds.
# 20200217_fin009.tif
# Finished NPS01_036 in 6 seconds.
# Finished everything in 78 seconds.
# 20200217_fin008
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200217_fin008.tif
# Image load took 0 seconds.
# 20200217_fin008.tif
# Finished NPS01_029 in 2 seconds.
# 20200217_fin008.tif
# Finished NPS01_030 in 3 seconds.
# 20200217_fin008.tif
# Finished NPS01_031 in 4 seconds.
# 20200217_fin008.tif
# Finished NPS01_032 in 5 seconds.
# Finished everything in 84 seconds.
# 20200214_fin006
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200214_fin006.tif
# Image load took 0 seconds.
# 20200214_fin006.tif
# Finished NPS01_021 in 1 seconds.
# 20200214_fin006.tif
# Finished NPS01_022 in 2 seconds.
# 20200214_fin006.tif
# Finished NPS01_023 in 4 seconds.
# 20200214_fin006.tif
# Finished NPS01_024 in 5 seconds.
# Finished everything in 89 seconds.
# 20200224_fin013
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200224_fin013.tif
# Image load took 0 seconds.
# 20200224_fin013.tif
# Finished NPS01_049 in 1 seconds.
# 20200224_fin013.tif
# Finished NPS01_050 in 3 seconds.
# 20200224_fin013.tif
# Finished NPS01_051 in 5 seconds.
# 20200224_fin013.tif
# Finished NPS01_052 in 7 seconds.
# Finished everything in 97 seconds.
# 20200221_fin011
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200221_fin011.tif
# Image load took 0 seconds.
# 20200221_fin011.tif
# Finished NPS01_041 in 2 seconds.
# 20200221_fin011.tif
# Finished NPS01_042 in 4 seconds.
# 20200221_fin011.tif
# Finished NPS01_043 in 6 seconds.
# 20200221_fin011.tif
# Finished NPS01_044 in 7 seconds.
# Finished everything in 105 seconds.
# 20200224_fin014
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200224_fin014.tif
# Image load took 0 seconds.
# 20200224_fin014.tif
# Finished NPS01_053 in 1 seconds.
# 20200224_fin014.tif
# Finished NPS01_054 in 2 seconds.
# 20200224_fin014.tif
# Finished NPS01_055 in 4 seconds.
# 20200224_fin014.tif
# Finished NPS01_056 in 4 seconds.
# Finished everything in 110 seconds.
# 20200224_fin015
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200224_fin015.tif
# Image load took 0 seconds.
# 20200224_fin015.tif
# Finished NPS01_057 in 1 seconds.
# 20200224_fin015.tif
# Finished NPS01_058 in 2 seconds.
# 20200224_fin015.tif
# Finished NPS01_059 in 4 seconds.
# 20200224_fin015.tif
# Finished NPS01_060 in 5 seconds.
# Finished everything in 115 seconds.
# 20200221_fin010
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200221_fin010.tif
# Image load took 0 seconds.
# 20200221_fin010.tif
# Finished NPS01_037 in 1 seconds.
# 20200221_fin010.tif
# Finished NPS01_038 in 4 seconds.
# 20200221_fin010.tif
# Finished NPS01_039 in 5 seconds.
# 20200221_fin010.tif
# Finished NPS01_040 in 8 seconds.
# Finished everything in 123 seconds.
# 20200221_fin012
# /Users/emilyfryer/Desktop/Neuroplant/Images/20200221_fin012.tif
# Image load took 0 seconds.
# 20200221_fin012.tif
# Finished NPS01_045 in 2 seconds.
# 20200221_fin012.tif
# Finished NPS01_046 in 4 seconds.
# 20200221_fin012.tif
# Finished NPS01_047 in 6 seconds.
# 20200221_fin012.tif
# Finished NPS01_048 in 8 seconds.
# Finished everything in 131 seconds.
