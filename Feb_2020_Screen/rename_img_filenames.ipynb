# %% [markdown]
# ## Correcting the oversights in image file naming conventions for the February screen
#  1. We sequentially named ALL of the image files which had the unfortunate consequence of  the pre and post images not being connected. As a result, the February screening image file names need to be renamed for image analysis. For example, 20200210_01_pre001.tif are the pre images for the all of the plates in 20200210_04_fin004.tif. This error has been noted and we will adjust for future screens.
#  2. We will elimante the 2nd numerical identifier in future assays as the scanner software incriments for us. For example: 20200210_01_pre001.tif will become 20200210_pre001.tif in future assays

# %%
import os
import pandas as pd
import glob
import pathlib
import fnmatch
import re

# %% [markdown]
# ## Loading the image folder, retreiving filenames as originally entered and returning modified names to the respective images.
#
# #### Removing the arbitrary middle value, example above

# %%
directory = "/Users/emilyfryer/Desktop/Neuroplant/Images/"

# %%
for filename in os.listdir(directory):
    old = os.path.join(directory, filename)
    new = os.path.join(directory, filename[:9] + filename[12:])
    os.rename(old, new)

# %% [markdown]
# #### Creating lists of pre and fin filenames that can be sorted in ascending order. We need to do this because the files are not read in in numerical or alphabetical order.

# %%
image_folder = pathlib.Path("/Users/emilyfryer/Desktop/Neuroplant/Images/")

# %%
pre_list = []
[pre_list.append(img.name) for img in image_folder.glob('*pre*')]

fin_list = []
[fin_list.append(img.name) for img in image_folder.glob('*fin*')]
print(fin_list)
# Out:
# ['.20200217_fin007.tif.icloud', '20200210_fin003.tif', '20200228_fin017.tif', '20200228_fin016.tif', '.20200210_fin002.tif.icloud', '.20200210_fin001.tif.icloud', '20200228_fin018.tif', '20200214_fin004.tif', '20200214_fin005.tif', '20200217_fin009.tif', '20200217_fin008.tif', '.20200214_fin006.tif.icloud', '20200224_fin013.tif', '20200221_fin011.tif', '20200224_fin014.tif', '20200224_fin015.tif', '20200221_fin010.tif', '20200221_fin012.tif']

# %% [markdown]
# #### Creating functions that will sort the filenames in ascending order based on numeric values in the file name string

# %%
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)',text) ]

pre_list.sort(key=natural_keys)
fin_list.sort(key=natural_keys)
print(fin_list)
# Out:
# ['20200210_fin003.tif', '20200214_fin004.tif', '20200214_fin005.tif', '20200217_fin008.tif', '20200217_fin009.tif', '20200221_fin010.tif', '20200221_fin011.tif', '20200221_fin012.tif', '20200224_fin013.tif', '20200224_fin014.tif', '20200224_fin015.tif', '20200228_fin016.tif', '20200228_fin017.tif', '20200228_fin018.tif', '.20200210_fin001.tif.icloud', '.20200210_fin002.tif.icloud', '.20200214_fin006.tif.icloud', '.20200217_fin007.tif.icloud']

# %% [markdown]
# #### Replacing the old file names with new ones based on the index value of the sorted lists above. Now the pre and fin images will map to each other based on their numerical values.
# <p>For example: 20200228_pre018.tif and 20200228_fin018.tif<p>

# %%
for filename in os.listdir(directory):
    if fnmatch.fnmatch(filename, '*pre*'):
        if (filename in pre_list):
            index_val = int(pre_list.index(filename)) + 1
            if index_val >= 10:
                old = os.path.join(directory, filename)
                new = os.path.join(directory, filename[:12] + '0' + str(index_val) + '.tif')
                os.rename(old, new)
                
            else:
                old = os.path.join(directory, filename)
                new = os.path.join(directory, filename[:12] + '00' + str(index_val) + '.tif')
                os.rename(old, new)
    elif fnmatch.fnmatch(filename, '*fin*'):
        if (filename in fin_list):
            index_val = int(fin_list.index(filename)) + 1
            if index_val >= 10:
                old = os.path.join(directory, filename)
                new = os.path.join(directory, filename[:12] + '0' + str(index_val) + '.tif')
                os.rename(old, new)
            else:
                old = os.path.join(directory, filename)
                new = os.path.join(directory, filename[:12] + '00' + str(index_val) + '.tif')
                os.rename(old, new)

# %% [markdown]
# ## Now we need to modify filenames in the metadata so they match the new filenames in the directory
#
# #### Read in the image metadata

# %%
data = pd.read_csv("/Users/emilyfryer/Desktop/feb_analysis/metadata/Feb2020_ImageData (Responses) - Form Responses 1.csv")

# %%
# Checking dataframe the structure and headers
data.head()
# Out:
#        Timestamp Name of individual capturing image:    Date:  \
# 3  2/10/20 14:55                               Emily  2/10/20
# 4  2/10/20 15:03                               Emily  2/10/20
# 5  2/10/20 15:06                               Emily  2/10/20
# 0  2/10/20 11:04                               Emily  2/10/20
# 1  2/10/20 11:14                               Emily  2/10/20
#
#       Image file name: Is this the pre or post assay image?  \
# 3  20200210_fin004.tif                                 Post
# 4  20200210_fin005.tif                                 Post
# 5  20200210_fin006.tif                                 Post
# 0  20200210_pre001.tif                                  Pre
# 1  20200210_pre002.tif                                  Pre
#
#   Plate number in slot 1: Plate number in slot 2: Plate number in slot 3:  \
# 3               NPS01_001               NPS01_002               NPS01_003
# 4               NPS01_005               NPS01_006               NPS01_007
# 5               NPS01_009               NPS01_010               NPS01_011
# 0               NPS01_001               NPS01_002               NPS01_003
# 1               NPS01_005               NPS01_006               NPS01_007
#
#   Plate number in slot 4:  Compound in slot 1:       Compound in slot 2:  \
# 3               NPS01_004             Vanillin              Theophylline
# 4               NPS01_008        Physostigmine               Theobromine
# 5               NPS01_012  Synephrine tartrate  Anisodamine hydrobromide
# 0               NPS01_004             Vanillin              Theophylline
# 1               NPS01_008        Physostigmine               Theobromine
#
#       Compound in slot 3:    Compound in slot 4:   Filenames_modified
# 3           Valproic acid  Quinine hydrochloride  20200210_fin001.tif
# 4  Lobeline hydrochloride                   DMSO  20200210_fin002.tif
# 5   4-hydroxybenzoic acid                Carvone  20200210_fin003.tif
# 0           Valproic acid  Quinine hydrochloride  20200210_pre001.tif
# 1  Lobeline hydrochloride                   DMSO  20200210_pre002.tif

# %% [markdown]
# 2. Removing the uneccessary middle values

# %%
data['Image file name:'] = data['Image file name:'].apply(lambda x: x[:9] + x[12:])

# %% [markdown]
# #### Sorting dataframe by file name values so we can be sure that the dataframe will merge appropriatley with the new list of file names generated below

# %%
data = data.sort_values(by=['Image file name:'])
data
# Out:
#         Timestamp Name of individual capturing image:    Date:  \
# 3   2/10/20 14:55                               Emily  2/10/20
# 18               NPS01_040  Phenylethylamine hydrochloride
# 19               NPS01_044                         Carvone
# 20               NPS01_048                   Valproic acid
# 21               NPS01_040  Phenylethylamine hydrochloride
# 23               NPS01_048                   Valproic acid
# 22               NPS01_044                         Carvone
# 27               NPS01_052             Synephrine tartrate
# 28               NPS01_056           Quinine hydrochloride
# 29               NPS01_060                        Vanillin
# 24               NPS01_052             Synephrine tartrate
# 25               NPS01_056           Quinine hydrochloride
# 26               NPS01_060                        Vanillin
# 33               NPS01_064                        Curcumin
# 34               NPS01_068                      Picrotoxin
# 35               NPS01_072                       Quercetin
# 30               NPS01_064                        Curcumin
# 31               NPS01_068                      Picrotoxin
# 32               NPS01_072                       Quercetin
#
#          Compound in slot 2:             Compound in slot 3:  \
# 3               Theophylline                   Valproic acid
# 4                Theobromine          Lobeline hydrochloride
# 5   Anisodamine hydrobromide           4-hydroxybenzoic acid
# 0               Theophylline                   Valproic acid
# 1                Theobromine          Lobeline hydrochloride
# 2   Anisodamine hydrobromide           4-hydroxybenzoic acid
# 12                   Brucine                   Valproic acid
# 13                Picrotoxin                      Securinine
# 14                     Rutin  Phenylethylamine hydrochloride
# 6                    Brucine                   Valproic acid
# 7                 Picrotoxin                      Securinine
# 8                      Rutin  Phenylethylamine hydrochloride
# 15    Lobeline hydrochloride        Anisodamine hydrobromide
# 16                  Vanillin                            DMSO
# 17             Physostigmine                    Theophylline
# 9     Lobeline hydrochloride        Anisodamine hydrobromide
# 10                  Vanillin                            DMSO
# 11             Physostigmine                    Theophylline
# 18                   Jasmone                      Naringenin
# 19                   Brucine                            DMSO
# 20                  Curcumin                       Quercetin
# 21                   Jasmone                      Naringenin
# 23                  Curcumin                       Quercetin
# 22                   Brucine                            DMSO
# 27                   Carvone                     Theobromine
# 28    Lobeline hydrochloride           4-hydroxybenzoic acid
# 29             Physostigmine                   Valproic acid
# 24                   Carvone                     Theobromine
# 25    Lobeline hydrochloride           4-hydroxybenzoic acid
# 26             Physostigmine                   Valproic acid
# 33                   Carvone                           Rutin
# 34                   Jasmone                         Brucine
# 35                Securinine                   Valproic acid
# 30                   Carvone                           Rutin
# 31                   Jasmone                         Brucine
# 32                Securinine                   Valproic acid
#
#                Compound in slot 4:
# 3            Quinine hydrochloride
# 4                             DMSO
# 5                          Carvone
# 0            Quinine hydrochloride
# 1                             DMSO
# 2                          Carvone
# 12                        Curcumin
# 13                            DMSO
# 14                         Carvone
# 6                         Curcumin
# 7                             DMSO
# 8                          Carvone
# 15           4-hydroxybenzoic acid
# 16                     Theobromine
# 17             Synephrine tartrate
# 9            4-hydroxybenzoic acid
# 10                     Theobromine
# 11             Synephrine tartrate
# 18                           Rutin
# 19                      Picrotoxin
# 20                      Securinine
# 21                           Rutin
# 23                      Securinine
# 22                      Picrotoxin
# 27                            DMSO
# 28                    Theophylline
# 29        Anisodamine hydrobromide
# 24                            DMSO
# 25                    Theophylline
# 26        Anisodamine hydrobromide
# 33                            DMSO
# 34                      Naringenin
# 35  Phenylethylamine hydrochloride
# 30                            DMSO
# 31                      Naringenin
# 32  Phenylethylamine hydrochloride

# %% [markdown]
# #### Retreiving the newly created file names as a list, sorting them to match the order of the dataframe above, merging the list and dataframe together. This could have been done in the 'for-loop' above but was overlooked.

# %%
new_names=[]
for filename in os.listdir(directory):
    if filename != '.DS_Store':
        new_names.append(filename)
new_names.sort()

# %%
data['Filenames_modified'] = new_names
data.head()
# Out:
#        Timestamp Name of individual capturing image:    Date:  \
# 3  2/10/20 14:55                               Emily  2/10/20
# 4  2/10/20 15:03                               Emily  2/10/20
# 5  2/10/20 15:06                               Emily  2/10/20
# 0  2/10/20 11:04                               Emily  2/10/20
# 1  2/10/20 11:14                               Emily  2/10/20
#
#       Image file name: Is this the pre or post assay image?  \
# 3  20200210_fin004.tif                                 Post
# 4  20200210_fin005.tif                                 Post
# 5  20200210_fin006.tif                                 Post
# 0  20200210_pre001.tif                                  Pre
# 1  20200210_pre002.tif                                  Pre
#
#   Plate number in slot 1: Plate number in slot 2: Plate number in slot 3:  \
# 3               NPS01_001               NPS01_002               NPS01_003
# 4               NPS01_005               NPS01_006               NPS01_007
# 5               NPS01_009               NPS01_010               NPS01_011
# 0               NPS01_001               NPS01_002               NPS01_003
# 1               NPS01_005               NPS01_006               NPS01_007
#
#   Plate number in slot 4:  Compound in slot 1:       Compound in slot 2:  \
# 3               NPS01_004             Vanillin              Theophylline
# 4               NPS01_008        Physostigmine               Theobromine
# 5               NPS01_012  Synephrine tartrate  Anisodamine hydrobromide
# 0               NPS01_004             Vanillin              Theophylline
# 1               NPS01_008        Physostigmine               Theobromine
#
#       Compound in slot 3:    Compound in slot 4:   Filenames_modified
# 3           Valproic acid  Quinine hydrochloride  20200210_fin001.tif
# 4  Lobeline hydrochloride                   DMSO  20200210_fin002.tif
# 5   4-hydroxybenzoic acid                Carvone  20200210_fin003.tif
# 0           Valproic acid  Quinine hydrochloride  20200210_pre001.tif
# 1  Lobeline hydrochloride                   DMSO  20200210_pre002.tif

# %%
data.to_csv("/Users/emilyfryer/Desktop/feb_analysis/metadata/modified_image_data.csv")

# %%
batch = pd.read_csv('/Users/emilyfryer/Desktop/feb_analysis/metadata/Assay Batch Data (Responses) - Form Responses 1.csv')

# %%
batch.head()
# Out:
#             Timestamp Recorder's Name:      Date:  Temperature (C):  \
# 0  2/10/2020 15:15:50   Sylvia Fechner  2/10/2020              20.3
# 1  2/14/2020 15:03:56            Emily  2/14/2020              20.0
# 2  2/17/2020 13:30:48      Tessa Logan  2/17/2020              23.7
# 3  2/21/2020 17:03:45            Emily  2/21/2020              21.6
# 4  2/24/2020 13:20:39   Sylvia Fechner  2/24/2020              23.3
#
#      Humidity: Date chemotaxis plates were poured: Worm Strain in Well P:  \
# 0  13.65 (low)                            2/5/2020                     N2
# 1          37%                            2/5/2020                  Osm-9
# 2          25%                           2/12/2020                  Tax-4
# 3           Lo                            2/5/2020                 Double
# 4           33                           2/12/2020                  Tax-4
#
#   Start Time for Plating Worms End Time for Plating Worms  \
# 0                   1:05:00 PM                 1:36:00 PM
# 1                  12:52:00 PM                 1:18:00 PM
# 2                  11:49:00 AM                12:20:00 PM
# 3                  11:23:00 AM                11:55:00 AM
# 4                  12:33:00 PM                12:58:00 PM
#
#   Chemotaxis Start Time: Chemotaxis End Time:  \
# 0             1:36:00 PM           1:55:00 PM
# 1             1:30:00 PM           2:30:00 PM
# 2            12:35:00 PM           1:35:00 PM
# 3            12:10:00 PM           1:10:00 PM
# 4             1:19:00 PM           2:19:00 PM
#
#                                    Additional notes: Worm Strain in Well Q:.1  \
# 0                       1:56 start time after drying                    Osm-9
# 1  Plate ID: NPS01_021 Well P: Solvent side has ~...                       N2
# 2  Worm washing started 11:20; plate 27 and 28 th...                   Double
# 3  1/2 of chemotaxis plates poured on 12/5/20 and...                    Tax-4
# 4  half plates poured on 02/12, other half 02/19....                    Osm-9
#
#   Worm Strain in Well R:.1 Worm Strain in Well S:.1  \
# 0                    Tax-4                   Double
# 1                    Tax-4                   Double
# 2                       N2                    Osm-9
# 3                    Osm-9                       N2
# 4                   Double                       N2
#
#   Start Time Compounded Added to Plates: End Time Compounded Added to Plates:  \
# 0                            12:05:00 PM                                  NaN
# 1                            11:40:00 AM                          11:58:00 AM
# 2                            10:51:00 AM                          11:05:00 AM
# 3                            10:35:00 AM                          10:45:00 AM
# 4                            12:02:00 PM                          12:16:00 PM
#
#   Modified_date
# 0      20200210
# 1      20200214
# 2      20200217
# 3      20200221
# 4      20200224

# %%
def modify_dates(date):
    month = '0' + date[:1]
    day = date[2:4]
    year = date[5:]
    mod_date = year+month+day
    return(mod_date)

batch['Modified_date'] = batch.apply(lambda x: modify_dates(x['Date:']),axis=1)

# %% [markdown]
# #### Dropping unecessary column values and exporting the new dataframe as a .csv to be used for the image analysis

# %%
batch = batch.drop(columns=['Worm Strain in Well P: [Tax-4]', 'Worm Strain in Well P: [Osm-9]','Worm Strain in Well Q:','Worm Strain in Well P: [Double]', 'Worm Strain in Well R:','Worm Strain in Well S:'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-985c4463c822> in <module>
# ----> 1 batch = batch.drop(columns=['Worm Strain in Well P: [Tax-4]', 'Worm Strain in Well P: [Osm-9]','Worm Strain in Well Q:','Worm Strain in Well P: [Double]', 'Worm Strain in Well R:','Worm Strain in Well S:'])
#
# ~/anaconda3/envs/neuroplant/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/anaconda3/envs/neuroplant/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/anaconda3/envs/neuroplant/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/anaconda3/envs/neuroplant/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Worm Strain in Well P: [Tax-4]' 'Worm Strain in Well P: [Osm-9]'\n 'Worm Strain in Well Q:' 'Worm Strain in Well P: [Double]'\n 'Worm Strain in Well R:' 'Worm Strain in Well S:'] not found in axis"

# %%
batch.to_csv('/Users/emilyfryer/Desktop/feb_analysis/metadata/feb_batch_data_mod.csv')
